# %%
! pip install tweepy==4.8.0
# Out:
# Collecting tweepy==4.8.0
#   Using cached tweepy-4.8.0-py2.py3-none-any.whl (77 kB)
# Collecting requests<3,>=2.27.0
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting oauthlib<4,>=3.2.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Collecting requests-oauthlib<2,>=1.2.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy==4.8.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy==4.8.0) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy==4.8.0) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy==4.8.0) (2.0.4)
# Installing collected packages: requests, oauthlib, requests-oauthlib, tweepy
#   Attempting uninstall: requests
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
#     Found existing installation: requests 2.26.0
#     Uninstalling requests-2.26.0:
#       Successfully uninstalled requests-2.26.0
# Successfully installed oauthlib-3.2.0 requests-2.27.1 requests-oauthlib-1.3.1 tweepy-4.8.0

# %%
# !pip install loguru
# Out:
# Requirement already satisfied: loguru in c:\programdata\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from loguru) (1.1.0)
# Requirement already satisfied: colorama>=0.3.4 in c:\programdata\anaconda3\lib\site-packages (from loguru) (0.4.4)

# %%
import os
import tweepy
import pandas
from loguru import logger
from sys import stderr

consumer_key = 'Bkzg44MHgtQszMvCdFhJEindf'
consumer_secret = '07vhPzTsz2r6QTy3TzISuDN0NJZNLt6SMBJIcGpbIFEZunwsGw'
access_token_key = '1512683317820239876-KphHJoncgY9fJpr5yw8WvEJdRYXZzF'
access_token_secret = 'gnUcKp6V7KrkUTLJbeTs5BCkiinevc1jkt181djFhUVmW'

bearer_token = "AAAAAAAAAAAAAAAAAAAAAKMxbQEAAAAAXL9RA3fotZaAejPj5lYjvdm9DaE%3DQ7BpU1w6ZxBBzEiOaKqBXA1lIuUISRptYlxAC6SaOBOA9Drfw9"

# %%
client = tweepy.Client(bearer_token=bearer_token, wait_on_rate_limit=True)

# %%
loglevel = os.getenv("LOGLEVEL", "INFO").upper()
logger.remove()
logger.add(stderr, level=loglevel)

collected_tweets = []
total_collected = 0

max_results = 100

for i, tweets in enumerate(tweepy.Paginator(
      client.search_recent_tweets,
      query = "Melbourne lang:en",
      start_time = "2001-01-01T00:00:00Z",
      tweet_fields = [
          'context_annotations',
          'created_at',
          'geo',
          'lang',
          'conversation_id',
          'public_metrics',
          'referenced_tweets',
          'in_reply_to_user_id',
      ],
      user_fields = [
          'profile_image_url',
          'name',
          'username',
          'created_at',
          'description',
          'entities',
          'location',
          'protected',
          'public_metrics',
          'verified',
      ],
      media_fields = [
          "media_key",
          "type",
          "duration_ms",
          "public_metrics",
          "width",
          "height",
          "preview_image_url",
          "alt_text"
      ],
      expansions = [
          "author_id",
          "referenced_tweets.id",
          "referenced_tweets.id.author_id",
          "attachments.media_keys",
      ],
      max_results=max_results
  )):
  max_results = max_results
  logger.info(f"Retrieved page {i+1} -- Collected {total_collected} tweets so far.")
  if not (tweets.includes.get('users')):
    break
  users = {u["id"]: u for u in tweets.includes['users']}
  media = {media["media_key"]: media for media in tweets.includes.get("media")} if tweets.includes.get("media") else None
  for j, tweet in enumerate(tweets.data):
    new_row = {}
        
    user = users[tweet.author_id]

    # get media
    attachments = tweet['attachments']
    media_keys = attachments.get('media_keys') if attachments else None
    tweet_media = media.get(media_keys[0] if media_keys else media_keys) if media else None

    new_row = {
                "tweet_text": tweet.text,
                "tweet_id": tweet.id,
                "tweet_created_at": tweet.created_at.strftime("%Y-%m-%d %H:%M:%S"),
                "tweet_public_metrics": tweet.public_metrics,
                "tweet_in_reply_to_user_id": tweet.in_reply_to_user_id,
                "tweet_conversation_id": tweet.conversation_id,
                "tweet_lang": tweet.lang,
                "tweet_context_annotations": tweet.context_annotations,
                "tweet_geo": tweet.geo,

                "author_id": user.id,
                "author_name": user.name,
                "author_username": user.username,
                "author_created_at": user.created_at.strftime("%Y-%m-%d %H:%M:%S"),
                "author_description": user.description,
                "author_entities": user.entities,
                "author_location": user.location,
                "author_is_protected": user.protected,
                "author_is_verified": user.verified,
                "author_profile_image_url": user.profile_image_url,
                "author_public_metrics": user.public_metrics,

                "media_key": tweet_media.get("media_key") if tweet_media else None,
                "media_type": tweet_media.get("media_type") if tweet_media else None,
                "media_duration_ms": tweet_media.get("duration_ms") if tweet_media else None,
                "media_height": tweet_media.get("height") if tweet_media else None,
                "media_width": tweet_media.get("width") if tweet_media else None,
                "media_preview_image_url": tweet_media.get("preview_image_url") if tweet_media else None,
                "media_alt_text": tweet_media.get("alt_text") if tweet_media else None,
                "media_view_count": (
                    tweet_media.get("public_metrics").get("view_count")
                        if tweet_media and 
                            tweet_media.get("public_metrics") and
                            tweet_media["public_metrics"].get("view_count")
                        else None
                )
            }

    collected_tweets.append(new_row)
    total_collected += 1
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# C:\Users\YUHENG~1\AppData\Local\Temp/ipykernel_18972/3292190994.py in <module>
#       8 max_results = 100
#       9
# ---> 10 for i, tweets in enumerate(tweepy.Paginator(
#      11       client.search_all_tweets,
#      12       query = "Melbourne lang:en",
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\pagination.py in __next__(self)
#      96             self.kwargs["pagination_token"] = pagination_token
#      97
# ---> 98         response = self.method(*self.args, **self.kwargs)
#      99
#     100         self.previous_token = response.meta.get("previous_token")
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\client.py in search_all_tweets(self, query, **params)
#    1143         """
#    1144         params["query"] = query
# -> 1145         return self._make_request(
#    1146             "GET", "/2/tweets/search/all", params=params,
#    1147             endpoint_parameters=(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     124         request_params = self._process_params(params, endpoint_parameters)
#     125
# --> 126         response = self.request(method, route, params=request_params,
#     127                                 json=json, user_auth=user_auth)
#     128
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\client.py in request(self, method, route, params, json, user_auth)
#      97                 raise Unauthorized(response)
#      98             if response.status_code == 403:
# ---> 99                 raise Forbidden(response)
#     100             if response.status_code == 404:
#     101                 raise NotFound(response)
#
# Forbidden: 403 Forbidden

# %%
print(collected_tweets[0].keys())
for tweet in collected_tweets:
  print(tweet)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# {'tweet_text': 'Sunday night May 1st @clarecmoore and I get to play a Melbourne launch for our album EVERYTHING WAS FUNNY. Playing two sets. A rare Melbourne show in our hometown.(Last one was May 2021) https://t.co/tX1Lq7rlrW', 'tweet_id': 1519471363740037120, 'tweet_created_at': '2022-04-28 00:19:38', 'tweet_public_metrics': {'retweet_count': 4, 'reply_count': 1, 'like_count': 17, 'quote_count': 0}, 'tweet_in_reply_to_user_id': None, 'tweet_conversation_id': 1519471363740037120, 'tweet_lang': 'en', 'tweet_context_annotations': [{'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855110285568299008', 'name': 'Melbourne', 'description': 'Melbourne'}}], 'tweet_geo': None, 'author_id':
 'author_entities': {'url': {'urls': [{'start': 0, 'end': 23, 'url': 'https://t.co/CChcCsFJ7f', 'expanded_url': 'http://www.tiktok.com/@arislovelanguage', 'display_url': 'tiktok.com/@arislovelangu…'}]}}, 'author_location': '🏳️\u200d🌈', 'author_is_protected': False, 'author_is_verified': False, 'author_profile_image_url': 'https://pbs.twimg.com/profile_images/1506994378241282055/FA1qegae_normal.jpg', 'author_public_metrics': {'followers_count': 980, 'following_count': 555, 'tweet_count': 12774, 'listed_count': 12}, 'media_key': None, 'media_type': None, 'media_duration_ms': None, 'media_height': None, 'media_width': None, 'media_preview_image_url': None, 'media_alt_text': None, 'media_view_count': None}
# {'tweet_text': 'RT @JerryAnyuon: We all need to re-watch the Battle Ground Melbourne documentary https://t.co/zwBAqBxwVT before the elections night.\n\n \u2066@To…', 'tweet_id': 1519470564112760834, 'tweet_created_at': '2022-04-28 00:16:27', 'tweet_public_metrics': {'retweet_count': 33, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'tweet_in_reply_to_user_id': None, 'tweet_conversation_id': 1519470564112760834, 'tweet_lang': 'en', 'tweet_context_annotations': [{'domain': {'id': '87', 'name': 'Movie Genre', 'description': 'A movie genre like Action'}, 'entity': {'id': '856976742166048769', 'name': 'Documentary films', 'description': 'Documentary'}}, {'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855110285568299008', 'name': 'Melbourne', 'description': 'Melbourne'}}], 'tweet_geo': None, 'author_id': 953906908854870016, 'author_name': 'JZXWorld', 'author_username': 'jzx_world', 'author_created_at': '2018-01-18 08:28:24', 'author_description': '', 'author_entities': None, 'author_location': None, 'author_is_protected': False, 'author_is_verified': False, 'author_profile_image_url': 'https://pbs.twimg.com/profile_images/1407273546502475782/zZe1VQo7_normal.jpg', 'author_public_metrics': {'followers_count': 446, 'following_count': 612, 'tweet_count': 4734, 'listed_count': 1}, 'media_key': None, 'media_type': None, 'media_duration_ms': None, 'media_height': None, 'media_width': None, 'media_preview_image_url': None, 'media_alt_text': None, 'media_view_count': None}
# {'tweet_text': 'RT @DocAvvers: @antoinette_news @GrogsGamut Yeah, right. Like the pieces that argued that the ‘Twitter mob attacks’ on Leigh Sales and Rach…', 'tweet_id': 1519470537310806016, 'tweet_created_at': '2022-04-28 00:16:21', 'tweet_public_metrics': {'retweet_count': 24, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'tweet_in_reply_to_user_id': None, 'tweet_conversation_id': 1519470537310806016, 'tweet_lang': 'en', 'tweet_context_annotations': [{'domain': {'id': '46', 'name': 'Brand Category', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '781974596752842752', 'name': 'Services'}}, {'domain': {'id': '47', 'name': 'Brand', 'description': 'Brands and Companies'}, 'entity': {'id': '10045225402', 'name': 'Twitter'}}], 'tweet_geo': None, 'author_id': 79062928, 'author_name': 'just Phil', 'author_username': 'Phil_B7', 'author_created_at': '2009-10-02 01:47:05', 'author_description': 'PMO is star chamber of conservative political operatives. Execs from Crosby Textor, Lib Party, NewsCorp, Min Council. They command & control EVERYTHING', 'author_entities': None, 'author_location': 'South East Queensland', 'author_is_protected': False, 'author_is_verified': False, 'author_profile_image_url': 'https://pbs.twimg.com/profile_images/579421747243409408/euecH_8h_normal.jpg', 'author_public_metrics': {'followers_count': 3649, 'following_count': 3901, 'tweet_count': 263872, 'listed_count': 124}, 'media_key': None, 'media_type': None, 'media_duration_ms': None, 'media_height': None, 'media_width': None, 'media_preview_image_url': None, 'media_alt_text': None, 'media_view_count': None}
# {'tweet_text': 'RT @PTIOverseas_: Shub-e-Dua organised in Melbourne by #PTI Victoria.\n\n#امپورٹڈ_حکومت_نامنظور\n#MarchAgainstImportedGovt\n#PTIOverseas https:…', 'tweet_id': 1519470516595306496, 'tweet_created_at': '2022-04-28 00:16:16', 'tweet_public_metrics': {'retweet_count': 3, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'tweet_in_reply_to_user_id': None, 'tweet_conversation_id': 1519470516595306496, 'tweet_lang': 'en', 'tweet_context_annotations': [{'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855110285568299008', 'name': 'Melbourne', 'description': 'Melbourne'}}], 'tweet_geo': None, 'author_id': 1255198393468620809, 'author_name': 'Amjad Hashmi', 'author_username': 'AskAmjadHashmi', 'author_created_at': '2020-04-28 18:14:39', 'author_description': '', 'author_entities': None, 'author_location': 'Al Riyadh', 'author_is_protected': False, 'author_is_verified': False, 'author_profile_image_url': 'https://pbs.twimg.com/profile_images/1289439898395607040/JF-DkHFo_normal.jpg', 'author_public_metrics': {'followers_count': 499, 'following_count': 1051, 'tweet_count': 53675, 'listed_count': 1}, 'media_key': None, 'media_type': None, 'media_duration_ms': None, 'media_height': None, 'media_width': None, 'media_preview_image_url': None, 'media_alt_text': None, 'media_view_count': None}
# ...
# {'tweet_text': 'RT @evelynblake0: @heidimur It’s actually illegal to travel on public transport without a mask in Melbourne. I’m shocked with some of the d…', 'tweet_id': 1519446041078075392, 'tweet_created_at': '2022-04-27 22:39:00', 'tweet_public_metrics': {'retweet_count': 7, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'tweet_in_reply_to_user_id': None, 'tweet_conversation_id': 1519446041078075392, 'tweet_lang': 'en', 'tweet_context_annotations': [{'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Entity Service related Events domain'}, 'entity': {'id': '1517623051860414465', 'name': 'World Environment Day'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '839159814991167489', 'name': 'Travel', 'description': 'Travel'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '839160129752686593', 'name': 'General Travel', 'description': 'General Travel'}}, {'domain': {'id': '67', 'name': 'Interests and Hobbies', 'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'}, 'entity': {'id': '839161975712067584', 'name': 'Travel Actions', 'description': 'This entity includes all conversations about travel and vacation.'}}, {'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855110285568299008', 'name': 'Melbourne', 'description': 'Melbourne'}}], 'tweet_geo': None, 'author_id': 3015305734, 'author_name': 'Saxdude26 #DisabledButProud #RaymanRedemption', 'author_username': 'Saxdude26', 'author_created_at': '2015-02-03 20:31:20', 'author_description': "Hey guys, Saxdude26 here. I'm an energetic Aussie who does Let's Plays, music covers, OST medleys and montage tributes. And I draw stuff occasionally. (He/Him)", 'author_entities': {'url': {'urls': [{'start': 0, 'end': 23, 'url': 'https://t.co/3th5hEXuVE', 'expanded_url': 'https://www.youtube.com/user/SaxdudeMaloyS26', 'display_url': 'youtube.com/user/SaxdudeMa…'}]}}, 'author_location': 'Australia', 'author_is_protected': False, 'author_is_verified': False, 'author_profile_image_url': 'https://pbs.twimg.com/profile_images/1436322297690738688/cYsTXVBe_normal.jpg', 'author_public_metrics': {'followers_count': 798, 'following_count': 1010, 'tweet_count': 61747, 'listed_count': 2}, 'media_key': None, 'media_type': None, 'media_duration_ms': None, 'media_height': None, 'media_width': None, 'media_preview_image_url': None, 'media_alt_text': None, 'media_view_count': None}
# {'tweet_text': 'Just posted a photo @ Melbourne, Victoria, Australia https://t.co/Y6v5GHlz13', 'tweet_id': 1519446034337861632, 'tweet_created_at': '2022-04-27 22:38:59', 'tweet_public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'tweet_in_reply_to_user_id': None, 'tweet_conversation_id': 1519446034337861632, 'tweet_lang': 'en', 'tweet_context_annotations': [{'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855110285568299008', 'name': 'Melbourne', 'description': 'Melbourne'}}], 'tweet_geo': None, 'author_id': 1371686004, 'author_name': 'PetHaus', 'author_username': 'HelloPetHaus', 'author_created_at': '2013-04-22 09:26:02', 'author_description': 'Battle Jackets for dogs! We make rock and metal battle jackets for dogs with attitude. Follow the adventures of our dog Willie.', 'author_entities': {'url': {'urls': [{'start': 0, 'end': 22, 'url': 'http://t.co/bScA9uZY7q', 'expanded_url': 'http://pethaus.com.au/', 'display_url': 'pethaus.com.au'}]}}, 'author_location': 'Melbourne, Australia', 'author_is_protected': False, 'author_is_verified': False, 'author_profile_image_url': 'https://pbs.twimg.com/profile_images/458152030175899648/oF_aQytN_normal.jpeg', 'author_public_metrics': {'followers_count': 312, 'following_count': 272, 'tweet_count': 2875, 'listed_count': 6}, 'media_key': None, 'media_type': None, 'media_duration_ms': None, 'media_height': None, 'media_width': None, 'media_preview_image_url': None, 'media_alt_text': None, 'media_view_count': None}
# {'tweet_text': 'RT @9NewsMelb: A bombshell investigation has found the culture within the Victorian Labor Party is "rotten" and encouraged the serious misu…', 'tweet_id': 1519445997356666880, 'tweet_created_at': '2022-04-27 22:38:50', 'tweet_public_metrics': {'retweet_count': 348, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'tweet_in_reply_to_user_id': None, 'tweet_conversation_id': 1519445997356666880, 'tweet_lang': 'en', 'tweet_context_annotations': [], 'tweet_geo': None, 'author_id': 923394129584824321, 'author_name': 'Portuguese Irish Australian Woman', 'author_username': 'stamford02', 'author_created_at': '2017-10-26 03:41:31', 'author_description': 'Opinionated, loyal and ferociously defensive of those I love. Some would say a humanitarian, I believe I am an equalist!', 'author_entities': None, 'author_location': 'Melbourne, Australia ', 'author_is_protected': False, 'author_is_verified': False, 'author_profile_image_url': 'https://pbs.twimg.com/profile_images/1518669400252899328/WTUUl3VE_normal.jpg', 'author_public_metrics': {'followers_count': 34, 'following_count': 140, 'tweet_count': 3261, 'listed_count': 0}, 'media_key': None, 'media_type': None, 'media_duration_ms': None, 'media_height': None, 'media_width': None, 'media_preview_image_url': None, 'media_alt_text': None, 'media_view_count': None}
# {'tweet_text': 'RT @HinduHate: Bhindranwale billboard was seen in Melbourne, Aus. Amar Singh of Turban 4 Australia, a Khalistani group, was awarded Citizen…', 'tweet_id': 1519445959284985856, 'tweet_created_at': '2022-04-27 22:38:41', 'tweet_public_metrics': {'retweet_count': 191, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'tweet_in_reply_to_user_id': None, 'tweet_conversation_id': 1519445959284985856, 'tweet_lang': 'en', 'tweet_context_annotations': [{'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855110285568299008', 'name': 'Melbourne', 'description': 'Melbourne'}}], 'tweet_geo': None, 'author_id': 35343837, 'author_name': 'अतुल', 'author_username': 'amz360', 'author_created_at': '2009-04-25 23:44:00', 'author_description': '', 'author_entities': {'url': {'urls': [{'start': 0, 'end': 23, 'url': 'https://t.co/sG1bJyqP3I', 'expanded_url': 'http://ikashmir.net/', 'display_url': 'ikashmir.net'}]}}, 'author_location': None, 'author_is_protected': False, 'author_is_verified': False, 'author_profile_image_url': 'https://pbs.twimg.com/profile_images/1193073116651483136/Pq3vR9xF_normal.jpg', 'author_public_metrics': {'followers_count': 4631, 'following_count': 939, 'tweet_count': 76888, 'listed_count': 139}, 'media_key': None, 'media_type': None, 'media_duration_ms': None, 'media_height': None, 'media_width': None, 'media_preview_image_url': None, 'media_alt_text': None, 'media_view_count': None}
# {'tweet_text': "RT @MazherArshad: Pakistan batters must be keeping an eye on Umran Malik's bowling. They could face him on October 23 in Melbourne and, bef…", 'tweet_id': 1519445883217088512, 'tweet_created_at': '2022-04-27 22:38:23', 'tweet_public_metrics': {'retweet_count': 264, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'tweet_in_reply_to_user_id': None, 'tweet_conversation_id': 1519445883217088512, 'tweet_lang': 'en', 'tweet_context_annotations': [{'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855110285568299008', 'name': 'Melbourne', 'description': 'Melbourne'}}], 'tweet_geo': None, 'author_id': 1253081311948005377, 'author_name': 'Badroddin Zindran', 'author_username': 'BadroddinZ', 'author_created_at': '2020-04-22 22:01:06', 'author_description': 'new social worker\nelectro technician', 'author_entities': None, 'author_location': 'Shirpur, India', 'author_is_protected': False, 'author_is_verified': False, 'author_profile_image_url': 'https://pbs.twimg.com/profile_images/1345609635034583040/eAN30SYa_normal.jpg', 'author_public_metrics': {'followers_count': 22, 'following_count': 302, 'tweet_count': 6213, 'listed_count': 0}, 'media_key': None, 'media_type': None, 'media_duration_ms': None, 'media_height': None, 'media_width': None, 'media_preview_image_url': None, 'media_alt_text': None, 'media_view_count': None}
# {'tweet_text': 'RT @9NewsMelb: A bombshell investigation has found the culture within the Victorian Labor Party is "rotten" and encouraged the serious misu…', 'tweet_id': 1519445846580146176, 'tweet_created_at': '2022-04-27 22:38:14', 'tweet_public_metrics': {'retweet_count': 348, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'tweet_in_reply_to_user_id': None, 'tweet_conversation_id': 1519445846580146176, 'tweet_lang': 'en', 'tweet_context_annotations': [], 'tweet_geo': None, 'author_id': 508073596, 'author_name': 'steph', 'author_username': 'stephijohn', 'author_created_at': '2012-02-28 23:25:44', 'author_description': 'Still fully human', 'author_entities': None, 'author_location': 'Australia', 'author_is_protected': False, 'author_is_verified': False, 'author_profile_image_url': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'author_public_metrics': {'followers_count': 229, 'following_count': 306, 'tweet_count': 10613, 'listed_count': 1}, 'media_key': None, 'media_type': None, 'media_duration_ms': None, 'media_height': None, 'media_width': None, 'media_preview_image_url': None, 'media_alt_text': None, 'media_view_count': None}
# {'tweet_text': '“Talk about a bucket list moment! Tanya Batt, the Melbourne/Naarm-based artist who makes music as @BATTSMUSIC, is kickstarting her next career chapter with the help of certified indie rock star @sharonvanetten” - @DoubleJRadio 💙💙\n\nhttps://t.co/3UOxxqETqs', 'tweet_id': 1519445703499841536, 'tweet_created_at': '2022-04-27 22:37:40', 'tweet_public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 1}, 'tweet_in_reply_to_user_id': None, 'tweet_conversation_id': 1519445703499841536, 'tweet_lang': 'en', 'tweet_context_annotations': [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '1241034007413788672', 'name': 'Sharon Van Etten'}}, {'domain': {'id': '54', 'name': 'Musician', 'description': 'A musician in the world, like Adele or Bob Dylan'}, 'entity': {'id': '1241034007413788672', 'name': 'Sharon Van Etten'}}, {'domain': {'id': '55', 'name': 'Music Genre', 'description': 'A category for a musical style, like Pop, Rock, or Rap'}, 'entity': {'id': '806571747730341888', 'name': 'Rock', 'description': 'Rock'}}, {'domain': {'id': '55', 'name': 'Music Genre', 'description': 'A category for a musical style, like Pop, Rock, or Rap'}, 'entity': {'id': '849684194242338816', 'name': 'Alternative rock', 'description': 'Alternative'}}, {'domain': {'id': '55', 'name': 'Music Genre', 'description': 'A category for a musical style, like Pop, Rock, or Rap'}, 'entity': {'id': '1108100469778345984', 'name': 'Classic rock', 'description': 'Classic Rock'}}, {'domain': {'id': '55', 'name': 'Music Genre', 'description': 'A category for a musical style, like Pop, Rock, or Rap'}, 'entity': {'id': '806571747730341888', 'name': 'Rock', 'description': 'Rock'}}, {'domain': {'id': '55', 'name': 'Music Genre', 'description': 'A category for a musical style, like Pop, Rock, or Rap'}, 'entity': {'id': '849684394923016192', 'name': 'Indie rock', 'description': 'Indie spotlight'}}, {'domain': {'id': '156', 'name': 'Cities', 'description': 'Cities around the world'}, 'entity': {'id': '855110285568299008', 'name': 'Melbourne', 'description': 'Melbourne'}}], 'tweet_geo': None, 'author_id': 27984343, 'author_name': 'Mistletone', 'author_username': 'mistletone', 'author_created_at': '2009-03-31 22:44:18', 'author_description': 'Indie label, touring company & publicity haven, curated with devotion by Ash & Sophie Miles since 2006.', 'author_entities': {'url': {'urls': [{'start': 0, 'end': 23, 'url': 'https://t.co/vqxzswjVSL', 'expanded_url': 'http://mistletone.net', 'display_url': 'mistletone.net'}]}}, 'author_location': 'Melbourne, Australia', 'author_is_protected': False, 'author_is_verified': False, 'author_profile_image_url': 'https://pbs.twimg.com/profile_images/519617805285470208/TK9NjR6O_normal.jpeg', 'author_public_metrics': {'followers_count': 6887, 'following_count': 7420, 'tweet_count': 21619, 'listed_count': 118}, 'media_key': None, 'media_type': None, 'media_duration_ms': None, 'media_height': None, 'media_width': None, 'media_preview_image_url': None, 'media_alt_text': None, 'media_view_count': None}
# {'tweet_text': 'RT @9NewsMelb: A bombshell investigation has found the culture within the Victorian Labor Party is "rotten" and encouraged the serious misu…', 'tweet_id': 1519445651657920512, 'tweet_created_at': '2022-04-27 22:37:27', 'tweet_public_metrics': {'retweet_count': 348, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'tweet_in_reply_to_user_id': None, 'tweet_conversation_id': 1519445651657920512, 'tweet_lang': 'en', 'tweet_context_annotations': [], 'tweet_geo': None, 'author_id': 1324597387340378113, 'author_name': 'Lishra🇦🇺#KillTheBill', 'author_username': 'Lishra2', 'author_created_at': '2020-11-06 06:20:12', 'author_description': '', 'author_entities': None, 'author_location': None, 'author_is_protected': False, 'author_is_verified': False, 'author_profile_image_url': 'https://pbs.twimg.com/profile_images/1440549955303665672/s8UJkFp2_normal.jpg', 'author_public_metrics': {'followers_count': 218, 'following_count': 1083, 'tweet_count': 530, 'listed_count': 0}, 'media_key': None, 'media_type': None, 'media_duration_ms': None, 'media_height': None, 'media_width': None, 'media_preview_image_url': None, 'media_alt_text': None, 'media_view_count': None}
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
type(collected_tweets)
collected_tweets[0]
# Out:
# {'author_created_at': '2013-04-04 08:12:51',
#  'author_description': '',
#  'author_entities': None,
#  'author_id': 1326437888,
#  'author_is_protected': False,
#  'author_is_verified': False,
#  'author_location': 'Geelong',
#  'author_name': 'Maree Avery',
#  'author_profile_image_url': 'https://pbs.twimg.com/profile_images/3626035769/0d57280776853fbe5f8282c8af98fa0f_normal.jpeg',
#  'author_public_metrics': {'followers_count': 188,
#   'following_count': 475,
#   'listed_count': 0,
#   'tweet_count': 2391},
#  'author_username': 'mareeave',
#  'media_alt_text': None,
#  'media_duration_ms': None,
#  'media_height': None,
#  'media_key': None,
#  'media_preview_image_url': None,
#  'media_type': None,
#  'media_view_count': None,
#  'media_width': None,
#  'tweet_context_annotations': [],
#  'tweet_conversation_id': 1518180921966534656,
#  'tweet_created_at': '2022-04-24 10:51:52',
#  'tweet_geo': None,
#  'tweet_id': 1518180921966534656,
#  'tweet_in_reply_to_user_id': None,
#  'tweet_lang': 'en',
#  'tweet_public_metrics': {'like_count': 0,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 409},
#  'tweet_text': 'RT @GaryHay20023561: Morrison and co saying Labor backed China, but forgot this comment by Mr Morrison featuring similar language in an add…'}
